# %%
from pathlib import Path
import pandas as pd

# %%
import parsers.samtools as samtools
import csv
import os

# %%
files = None
with open(Path("/home/unicph.domain/glj523/samtools_file_list_examples.txt")) as f:
    files = [line.strip() for line in f if line.strip()]

# %%
samtools.parse_files(files, 'summary.tsv')
# Out:
# collecting metrics
# writing summary
# done

# %%
df = pd.read_csv('summary.tsv', sep='\t')

# %%
df
# Out:
#                           filename  raw total sequences  filtered sequences  \
# 0   Lib_LV7001903345_collapsed.txt             22567852                   0
# 1   Lib_LV7001903286_collapsed.txt               227008                   0
# 2   Lib_LV7001903292_collapsed.txt              3034146                   0
# 3   Lib_LV7001903370_collapsed.txt              2173912                   0
# 4   Lib_LV7001903276_collapsed.txt              1695827                   0
# 5   Lib_LV7001903273_collapsed.txt             10603172                   0
# 6   Lib_LV7001903362_collapsed.txt               180722                   0
# 7   Lib_LV7001903369_collapsed.txt                 6156                   0
# 8   Lib_LV7001903371_collapsed.txt             13945610                   0
# 9   Lib_LV7001903347_collapsed.txt               997200                   0
# 10  Lib_LV7001903372_collapsed.txt              7975372                   0
#
# ...
