# %%
from pathlib import Path
import pandas as pd

# %%
import parsers.fastqc as fastqc

# %%
files = Path("/home/unicph.domain/glj523/fastq_paths_single_lib.txt").read_text().splitlines()

# %%
df = fastqc.get_basic_stats(files)

# %%
df.to_csv("/home/unicph.domain/glj523/fastqc_basic_stats.csv", index=False)
# Out:
# Measure                                       Filename  \
# 0                  Lib_LV7009021867_collapsed.fastq.gz
# 1                  Lib_LV7009021867_collapsed.fastq.gz
# 2                  Lib_LV7009021867_collapsed.fastq.gz
# 3                  Lib_LV7009021867_collapsed.fastq.gz
# 4                    Lib_LV7009021867_L001_R1.fastq.gz
# 5                    Lib_LV7009021867_L001_R2.fastq.gz
# 6                    Lib_LV7009021867_L002_R1.fastq.gz
# 7                    Lib_LV7009021867_L002_R2.fastq.gz
# 8                    Lib_LV7009021867_L003_R1.fastq.gz
# 9                    Lib_LV7009021867_L003_R2.fastq.gz
# 10                   Lib_LV7009021867_L004_R1.fastq.gz
# 11                   Lib_LV7009021867_L004_R2.fastq.gz
# 12            Lib_LV7009021867_L001_collapsed.fastq.gz
# 13       Lib_LV7009021867_L001_collapsedtrunc.fastq.gz
# 14                   Lib_LV7009021867_L001_R1.fastq.gz
# 15                   Lib_LV7009021867_L001_R2.fastq.gz
# 16            Lib_LV7009021867_L001_singleton.fastq.gz
# 17            Lib_LV7009021867_L002_collapsed.fastq.gz
# 18       Lib_LV7009021867_L002_collapsedtrunc.fastq.gz
# 19                   Lib_LV7009021867_L002_R1.fastq.gz
# 20                   Lib_LV7009021867_L002_R2.fastq.gz
# 21            Lib_LV7009021867_L002_singleton.fastq.gz
# 22            Lib_LV7009021867_L003_collapsed.fastq.gz
# 23       Lib_LV7009021867_L003_collapsedtrunc.fastq.gz
# 24                   Lib_LV7009021867_L003_R1.fastq.gz
# 25                   Lib_LV7009021867_L003_R2.fastq.gz
# 26            Lib_LV7009021867_L003_singleton.fastq.gz
# 27            Lib_LV7009021867_L004_collapsed.fastq.gz
# 28       Lib_LV7009021867_L004_collapsedtrunc.fastq.gz
# 29                   Lib_LV7009021867_L004_R1.fastq.gz
# 30                   Lib_LV7009021867_L004_R2.fastq.gz
# 31            Lib_LV7009021867_L004_singleton.fastq.gz
#
# Measure                File type               Encoding Total Sequences  \
# 0        Conventional base calls  Sanger / Illumina 1.9        53357894
# 1        Conventional base calls  Sanger / Illumina 1.9        53084033
# 2        Conventional base calls  Sanger / Illumina 1.9       106326331
# 3        Conventional base calls  Sanger / Illumina 1.9        47503274
# 4        Conventional base calls  Sanger / Illumina 1.9        61102744
# 5        Conventional base calls  Sanger / Illumina 1.9        61102744
# 6        Conventional base calls  Sanger / Illumina 1.9        61688263
# 7        Conventional base calls  Sanger / Illumina 1.9        61688263
# 8        Conventional base calls  Sanger / Illumina 1.9        60567626
# 9        Conventional base calls  Sanger / Illumina 1.9        60567626
# 10       Conventional base calls  Sanger / Illumina 1.9        60681477
# 11       Conventional base calls  Sanger / Illumina 1.9        60681477
# 12       Conventional base calls  Sanger / Illumina 1.9        26870783
# 13       Conventional base calls  Sanger / Illumina 1.9           42407
# 14       Conventional base calls  Sanger / Illumina 1.9         5639841
# 15       Conventional base calls  Sanger / Illumina 1.9         5639841
# 16       Conventional base calls  Sanger / Illumina 1.9            2192
# 17       Conventional base calls  Sanger / Illumina 1.9        26625066
# 18       Conventional base calls  Sanger / Illumina 1.9           38455
# 19       Conventional base calls  Sanger / Illumina 1.9         5705251
# 20       Conventional base calls  Sanger / Illumina 1.9         5705251
# 21       Conventional base calls  Sanger / Illumina 1.9            2128
# 22       Conventional base calls  Sanger / Illumina 1.9        26592768
# 23       Conventional base calls  Sanger / Illumina 1.9           40361
# 24       Conventional base calls  Sanger / Illumina 1.9         5536619
# 25       Conventional base calls  Sanger / Illumina 1.9         5536619
# 26       Conventional base calls  Sanger / Illumina 1.9            2007
# 27       Conventional base calls  Sanger / Illumina 1.9        26237714
# 28       Conventional base calls  Sanger / Illumina 1.9           39732
# 29       Conventional base calls  Sanger / Illumina 1.9         5572908
# 30       Conventional base calls  Sanger / Illumina 1.9         5572908
# 31       Conventional base calls  Sanger / Illumina 1.9            2113
#
# Measure Total Bases Sequences flagged as poor quality Sequence length %GC  \
# 0           3.7 Gbp                                 0          30-191  48
# 1           3.7 Gbp                                 0          30-191  48
# 2           6.9 Gbp                                 0          30-191  49
# 3           3.4 Gbp                                 0          30-191  48
# 4           6.1 Gbp                                 0             101  56
# 5           6.1 Gbp                                 0             101  57
# 6           6.2 Gbp                                 0             101  56
# 7           6.2 Gbp                                 0             101  57
# 8           6.1 Gbp                                 0             101  56
# 9           6.1 Gbp                                 0             101  57
# 10          6.1 Gbp                                 0             101  56
# 11          6.1 Gbp                                 0             101  57
# 12          1.7 Gbp                                 0          30-191  49
# 13          2.5 Mbp                                 0          30-190  47
# 14        569.6 Mbp                                 0         100-101  62
# 15        569.6 Mbp                                 0          99-101  87
# 16        221.3 kbp                                 0          98-101  88
# 17          1.7 Gbp                                 0          30-191  49
# 18          2.3 Mbp                                 0          30-190  47
# 19        576.2 Mbp                                 0         100-101  62
# 20        576.2 Mbp                                 0         100-101  87
# 21        214.9 kbp                                 0             101  87
# 22          1.7 Gbp                                 0          30-191  49
# 23          2.4 Mbp                                 0          30-190  47
# 24        559.1 Mbp                                 0         100-101  62
# 25        559.1 Mbp                                 0             101  87
# 26        202.7 kbp                                 0             101  87
# 27          1.7 Gbp                                 0          30-191  49
# 28          2.4 Mbp                                 0          30-190  47
# 29        562.8 Mbp                                 0         100-101  62
# 30        562.8 Mbp                                 0             101  88
# 31        213.4 kbp                                 0             101  87
#
# Measure Total Deduplicated Percentage Basic Statistics status  \
# 0                   95.25457941435809                    pass
# 1                    95.3009835324874                    pass
# 2                   48.33621928858068                    pass
# 3                   95.15055564628528                    pass
# 4                  31.917588221616388                    pass
# 5                   33.25311689346882                    pass
# 6                  31.157520409972484                    pass
# 7                   32.57474173182614                    pass
# 8                  31.846836629626925                    pass
# 9                   33.29301260546817                    pass
# 10                 31.899326031397766                    pass
# 11                  33.31199349412218                    pass
# 12                  64.57647482194025                    pass
# 13                  90.71379725045394                    pass
# 14                 16.485611606518848                    pass
# 15                 19.527380125275783                    pass
# 16                 25.593065693430656                    pass
# 17                   64.6586217586659                    pass
# 18                  90.83604212716162                    pass
# 19                  15.64189261584304                    pass
# 20                   18.7830746177045                    pass
# 21                 26.033834586466163                    pass
# 22                  64.84792902737072                    pass
# 23                  91.32578479224995                    pass
# 24                 16.304543571401492                    pass
# 25                  19.37103829947544                    pass
# 26                  25.85949177877429                    pass
# 27                   64.7192524297244                    pass
# 28                  91.70945333736032                    pass
# 29                 15.864893927924259                    pass
# 30                  18.91853289560197                    pass
# 31                 26.455276857548508                    pass
#
# Measure Per base sequence quality status Per tile sequence quality status  \
# 0                                   pass                             fail
# 1                                   pass                             fail
# 2                                   pass                             warn
# 3                                   pass                             fail
# 4                                   pass                             pass
# 5                                   pass                             warn
# 6                                   pass                             warn
# 7                                   pass                             warn
# 8                                   pass                             warn
# 9                                   pass                             warn
# 10                                  pass                             warn
# 11                                  pass                             fail
# 12                                  pass                             fail
# 13                                  pass                             fail
# 14                                  pass                             warn
# 15                                  pass                             warn
# 16                                  pass                             fail
# 17                                  pass                             fail
# 18                                  pass                             fail
# 19                                  pass                             warn
# 20                                  pass                             warn
# 21                                  pass                             fail
# 22                                  pass                             fail
# 23                                  pass                             fail
# 24                                  pass                             pass
# 25                                  pass                             warn
# 26                                  pass                             fail
# 27                                  pass                             fail
# 28                                  pass                             fail
# 29                                  pass                             warn
# 30                                  pass                             fail
# 31                                  pass                             fail
#
# Measure Per sequence quality scores status Per base sequence content status  \
# 0                                     pass                             pass
# 1                                     pass                             pass
# 2                                     pass                             fail
# 3                                     pass                             pass
# 4                                     pass                             fail
# 5                                     pass                             fail
# 6                                     pass                             fail
# 7                                     pass                             fail
# 8                                     pass                             fail
# 9                                     pass                             fail
# 10                                    pass                             fail
# 11                                    pass                             fail
# 12                                    pass                             fail
# 13                                    pass                             warn
# 14                                    pass                             fail
# 15                                    pass                             fail
# 16                                    pass                             fail
# 17                                    pass                             fail
# 18                                    pass                             warn
# 19                                    pass                             fail
# 20                                    pass                             fail
# 21                                    pass                             fail
# 22                                    pass                             fail
# 23                                    pass                             fail
# 24                                    pass                             fail
# 25                                    pass                             fail
# 26                                    pass                             fail
# 27                                    pass                             fail
# 28                                    pass                             warn
# 29                                    pass                             fail
# 30                                    pass                             fail
# 31                                    pass                             fail
#
# Measure Per sequence GC content status Per base N content status  \
# 0                                 pass                      pass
# 1                                 pass                      pass
# 2                                 fail                      pass
# 3                                 pass                      pass
# 4                                 fail                      pass
# 5                                 fail                      pass
# 6                                 fail                      pass
# 7                                 fail                      pass
# 8                                 fail                      pass
# 9                                 fail                      pass
# 10                                fail                      pass
# 11                                fail                      pass
# 12                                fail                      pass
# 13                                fail                      warn
# 14                                fail                      pass
# 15                                fail                      pass
# 16                                fail                      warn
# 17                                fail                      pass
# 18                                fail                      warn
# 19                                fail                      pass
# 20                                fail                      pass
# 21                                fail                      warn
# 22                                fail                      pass
# 23                                fail                      warn
# 24                                fail                      pass
# 25                                fail                      pass
# 26                                fail                      warn
# 27                                fail                      pass
# 28                                fail                      warn
# 29                                fail                      pass
# 30                                fail                      pass
# 31                                fail                      warn
#
# Measure Sequence Length Distribution status  \
# 0                                      warn
# 1                                      warn
# 2                                      warn
# 3                                      warn
# 4                                      pass
# 5                                      pass
# 6                                      pass
# 7                                      pass
# 8                                      pass
# 9                                      pass
# 10                                     pass
# 11                                     pass
# 12                                     warn
# 13                                     warn
# 14                                     warn
# 15                                     warn
# 16                                     warn
# 17                                     warn
# 18                                     warn
# 19                                     warn
# 20                                     warn
# 21                                     pass
# 22                                     warn
# 23                                     warn
# 24                                     warn
# 25                                     pass
# 26                                     pass
# 27                                     warn
# 28                                     warn
# 29                                     warn
# 30                                     pass
# 31                                     pass
#
# Measure Sequence Duplication Levels status Overrepresented sequences status  \
# 0                                     pass                             pass
# 1                                     pass                             pass
# 2                                     fail                             fail
# 3                                     pass                             pass
# 4                                     fail                             fail
# 5                                     fail                             fail
# 6                                     fail                             fail
# 7                                     fail                             fail
# 8                                     fail                             fail
# 9                                     fail                             fail
# 10                                    fail                             fail
# 11                                    fail                             fail
# 12                                    warn                             fail
# 13                                    pass                             fail
# 14                                    fail                             fail
# 15                                    fail                             fail
# 16                                    fail                             fail
# 17                                    warn                             fail
# 18                                    pass                             fail
# 19                                    fail                             fail
# 20                                    fail                             fail
# 21                                    fail                             fail
# 22                                    warn                             fail
# 23                                    pass                             fail
# 24                                    fail                             fail
# 25                                    fail                             fail
# 26                                    fail                             fail
# 27                                    warn                             fail
# 28                                    pass                             fail
# 29                                    fail                             fail
# 30                                    fail                             fail
# 31                                    fail                             fail
#
# Measure Adapter Content status
# 0                         pass
# 1                         pass
# 2                         pass
# 3                         pass
# 4                         fail
# 5                         fail
# 6                         fail
# 7                         fail
# 8                         fail
# 9                         fail
# 10                        fail
# 11                        fail
# 12                        pass
# 13                        pass
# 14                        fail
# 15                        fail
# 16                        fail
# 17                        pass
# 18                        pass
# 19                        fail
# 20                        fail
# 21                        fail
# 22                        pass
# 23                        pass
# 24                        fail
# 25                        fail
# 26                        fail
# 27                        pass
# 28                        pass
# 29                        fail
# 30                        fail
# 31                        fail

# %%
df.to_csv("fastqc_basic_stats_LV7009021851.tsv", index=False, sep="\t")

# %%
merge_lanes['modules']['Basic Statistics']
# Out:
# {'status': 'pass',
#  'header_values': {},
#  'table': {'headers': ['Measure', 'Value'],
#   'rows': [{'Measure': 'Filename',
#     'Value': 'Lib_LV7008864206_collapsed.fastq.gz'},
#    {'Measure': 'File type', 'Value': 'Conventional base calls'},
#    {'Measure': 'Encoding', 'Value': 'Sanger / Illumina 1.9'},
#    {'Measure': 'Total Sequences', 'Value': '188989298'},
#    {'Measure': 'Total Bases', 'Value': '11 Gbp'},
#    {'Measure': 'Sequences flagged as poor quality', 'Value': '0'},
#    {'Measure': 'Sequence length', 'Value': '30-191'},
#    {'Measure': '%GC', 'Value': '60'}]}}

# %%
def get_basic_stats(results) -> pd.DataFrame:
    combined_df = pd.DataFrame()
    for result in results:
        status_data = [{'Measure': f"{k} status", 'Value': v['status']} for k, v in result['modules'].items()]
        basic_stats = result['modules']['Basic Statistics']['table']['rows']
        header_data = [{'Measure': i, 'Value': j} for k, v in result['modules'].items() for i, j in v['header_values'].items()]
        df = pd.DataFrame(basic_stats + header_data + status_data)
        df = df.set_index('Measure').T.reset_index(drop=True)
        combined_df = pd.concat([combined_df, df], ignore_index=True)
    return combined_df

# %%
res
# Out:
# Measure                                  Filename                File type  \
# 0        Lib_LV7008864206_L001_collapsed.fastq.gz  Conventional base calls
# 1             Lib_LV7008864206_collapsed.fastq.gz  Conventional base calls
#
# Measure               Encoding Total Sequences Total Bases  \
# 0        Sanger / Illumina 1.9        46694974     2.7 Gbp
# 1        Sanger / Illumina 1.9       188989298      11 Gbp
#
# Measure Sequences flagged as poor quality Sequence length %GC  \
# 0                                       0          30-191  60
# 1                                       0          30-191  60
#
# Measure Total Deduplicated Percentage Basic Statistics status  \
# 0                   73.97223323811349                    pass
# 1                   44.66736217565382                    pass
#
# Measure Per base sequence quality status Per tile sequence quality status  \
# 0                                   pass                             fail
# 1                                   pass                             fail
#
# Measure Per sequence quality scores status Per base sequence content status  \
# 0                                     pass                             warn
# 1                                     pass                             warn
#
# Measure Per sequence GC content status Per base N content status  \
# 0                                 fail                      pass
# 1                                 fail                      pass
#
# Measure Sequence Length Distribution status  \
# 0                                      warn
# 1                                      warn
#
# Measure Sequence Duplication Levels status Overrepresented sequences status  \
# 0                                     pass                             pass
# 1                                     fail                             pass
#
# Measure Adapter Content status
# 0                         pass
# 1                         pass

# %%
def combine_basic_stats(*results) -> pd.DataFrame:
    dfs = [get_basic_stats(result) for result in results]
    combined_df = pd.concat(dfs, ignore_index=True)
    return combined_df

# %%
res
# Out:
# Measure                                  Filename                File type  \
# 0        Lib_LV7008864206_L001_collapsed.fastq.gz  Conventional base calls
#
# Measure               Encoding Total Sequences Total Bases  \
# 0        Sanger / Illumina 1.9        46694974     2.7 Gbp
#
# Measure Sequences flagged as poor quality Sequence length %GC  \
# 0                                       0          30-191  60
#
# Measure Total Deduplicated Percentage Basic Statistics status  \
# 0                   73.97223323811349                    pass
#
# Measure Per base sequence quality status Per tile sequence quality status  \
# 0                                   pass                             fail
#
# Measure Per sequence quality scores status Per base sequence content status  \
# 0                                     pass                             warn
#
# Measure Per sequence GC content status Per base N content status  \
# 0                                 fail                      pass
#
# Measure Sequence Length Distribution status  \
# 0                                      warn
#
# Measure Sequence Duplication Levels status Overrepresented sequences status  \
# 0                                     pass                             pass
#
# Measure Adapter Content status
# 0                         pass

# %%
res
# Out:
#                                                   0   \
# 0  {'Measure': 'Basic Statistics status', 'Value'...
# 1  {'Measure': 'Basic Statistics status', 'Value'...
#
#                                                   1   \
# 0  {'Measure': 'Per base sequence quality status'...
# 1  {'Measure': 'Per base sequence quality status'...
#
#                                                   2   \
# 0  {'Measure': 'Per tile sequence quality status'...
# 1  {'Measure': 'Per tile sequence quality status'...
#
#                                                   3   \
# 0  {'Measure': 'Per sequence quality scores statu...
# 1  {'Measure': 'Per sequence quality scores statu...
#
#                                                   4   \
# 0  {'Measure': 'Per base sequence content status'...
# 1  {'Measure': 'Per base sequence content status'...
#
#                                                   5   \
# 0  {'Measure': 'Per sequence GC content status', ...
# 1  {'Measure': 'Per sequence GC content status', ...
#
#                                                   6   \
# 0  {'Measure': 'Per base N content status', 'Valu...
# 1  {'Measure': 'Per base N content status', 'Valu...
#
#                                                   7   \
# 0  {'Measure': 'Sequence Length Distribution stat...
# 1  {'Measure': 'Sequence Length Distribution stat...
#
#                                                   8   \
# 0  {'Measure': 'Sequence Duplication Levels statu...
# 1  {'Measure': 'Sequence Duplication Levels statu...
#
#                                                   9   \
# 0  {'Measure': 'Overrepresented sequences status'...
# 1  {'Measure': 'Overrepresented sequences status'...
#
#                                                   10  \
# 0  {'Measure': 'Adapter Content status', 'Value':...
# 1  {'Measure': 'Adapter Content status', 'Value':...
#
#                                                   11  \
# 0  {'Measure': 'Filename', 'Value': 'Lib_LV700886...
# 1  {'Measure': 'Filename', 'Value': 'Lib_LV700886...
#
#                                                   12  \
# 0  {'Measure': 'File type', 'Value': 'Conventiona...
# 1  {'Measure': 'File type', 'Value': 'Conventiona...
#
#                                                   13  \
# 0  {'Measure': 'Encoding', 'Value': 'Sanger / Ill...
# 1  {'Measure': 'Encoding', 'Value': 'Sanger / Ill...
#
#                                                   14  \
# 0  {'Measure': 'Total Sequences', 'Value': '18898...
# 1  {'Measure': 'Total Sequences', 'Value': '46694...
#
#                                                15  \
# 0   {'Measure': 'Total Bases', 'Value': '11 Gbp'}
# 1  {'Measure': 'Total Bases', 'Value': '2.7 Gbp'}
#
#                                                   16  \
# 0  {'Measure': 'Sequences flagged as poor quality...
# 1  {'Measure': 'Sequences flagged as poor quality...
#
#                                                   17  \
# 0  {'Measure': 'Sequence length', 'Value': '30-191'}
# 1  {'Measure': 'Sequence length', 'Value': '30-191'}
#
#                                   18  \
# 0  {'Measure': '%GC', 'Value': '60'}
# 1  {'Measure': '%GC', 'Value': '60'}
#
#                                                   19
# 0  {'Measure': 'Total Deduplicated Percentage', '...
# 1  {'Measure': 'Total Deduplicated Percentage', '...

# %%
res
# Out:
# Measure Basic Statistics status Per base sequence quality status  \
# 0                          pass                             pass
#
# Measure Per tile sequence quality status Per sequence quality scores status  \
# 0                                   fail                               pass
#
# Measure Per base sequence content status Per sequence GC content status  \
# 0                                   warn                           fail
#
# Measure Per base N content status Sequence Length Distribution status  \
# 0                            pass                                warn
#
# Measure Sequence Duplication Levels status Overrepresented sequences status  \
# 0                                     fail                             pass
#
# Measure Adapter Content status                             Filename  \
# 0                         pass  Lib_LV7008864206_collapsed.fastq.gz
#
# Measure                File type               Encoding Total Sequences  \
# 0        Conventional base calls  Sanger / Illumina 1.9       188989298
#
# Measure Total Bases Sequences flagged as poor quality Sequence length %GC  \
# 0            11 Gbp                                 0          30-191  60
#
# Measure Total Deduplicated Percentage
# 0                   44.66736217565382

# %%
pd.concat([get_basic_stats(merge_lanes), get_basic_stats(trim_l1)])
# Out:
# Measure                                  Filename                File type  \
# 0             Lib_LV7008864206_collapsed.fastq.gz  Conventional base calls
# 0        Lib_LV7008864206_L001_collapsed.fastq.gz  Conventional base calls
#
# Measure               Encoding Total Sequences Total Bases  \
# 0        Sanger / Illumina 1.9       188989298      11 Gbp
# 0        Sanger / Illumina 1.9        46694974     2.7 Gbp
#
# Measure Sequences flagged as poor quality Sequence length %GC  \
# 0                                       0          30-191  60
# 0                                       0          30-191  60
#
# Measure Total Deduplicated Percentage Basic Statistics status  \
# 0                   73.97223323811349                    pass
# 0                   73.97223323811349                    pass
#
# Measure Per base sequence quality status Per tile sequence quality status  \
# 0                                   pass                             fail
# 0                                   pass                             fail
#
# Measure Per sequence quality scores status Per base sequence content status  \
# 0                                     pass                             warn
# 0                                     pass                             warn
#
# Measure Per sequence GC content status Per base N content status  \
# 0                                 fail                      pass
# 0                                 fail                      pass
#
# Measure Sequence Length Distribution status  \
# 0                                      warn
# 0                                      warn
#
# Measure Sequence Duplication Levels status Overrepresented sequences status  \
# 0                                     fail                             pass
# 0                                     pass                             pass
#
# Measure Adapter Content status
# 0                         pass
# 0                         pass
