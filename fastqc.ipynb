# %%
import importlib
from parsers import fastqc

# %%
importlib.reload(fastqc)
# Out:
# <module 'parsers.fastqc' from '/home/glj523/GitHubRepoes/qc-parser/parsers/fastqc.py'>

# %%
path = "/datasets/caeg_production/libraries/LV7/008/891/LV7008891944/20260401_A23JH5FLT4/v1.0.8/4ebe3d1488023a26ec5b50b4e6a71f6b/"
res = fastqc.parse(path)

# %%
res.to_csv("fastqc_full_stats.csv", index=False)
