# %%
from pathlib import Path
from parsers import misc

# %%
meta_data = misc.parse_path_metadata("/datasets/caeg_production/libraries/LV7/001/856/LV7001856478/20230414_BHMGMJDSX5/v1.0.8/4ebe3d1488023a26ec5b50b4e6a71f6b/stats/reads/fastqc/derep/Lib_LV7001856478_collapsed_fastqc.zip")

# %%
meta_data
# Out:
# {'date': '20230414',
#  'flowcell_id': 'HMGMJDSX5',
#  'flowcell_side': 'B',
#  'pipeline_version': 'v1.0.8',
#  'pipeline_hash': '4ebe3d1488023a26ec5b50b4e6a71f6b',
#  'lane': 'collapsed',
#  'library_id': 'LV7001856478'}

# %%
23GYVVLT3
23JHGKLT4
23JJ7KLT4
222HKKYNX
